# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import random
import difflib
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import numpy as np
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score
from IPython.display import IFrame
import spotipy
import spotipy.util as util

# %%
playlist_final2= pd.read_csv("Playlist_Final.csv")
playlist_final2
# Out:
#       Unnamed: 0           artist  \
# 0              0     Taylor Swift
# 1              1     Thomas Rhett
# 2              2       Bruno Mars
# 3              3       Ed Sheeran
# 4              4       Ed Sheeran
# ...          ...              ...
# 6410        6419         deLillos
# 6411        6420             ABBA
# 6412        6421        Bob Seger
# 6413        6422        The Clash
# 6414        6423  Various Artists
#
#                                             album  \
# 0                                      reputation
# 1                                    Life Changes
# 2                                       24K Magic
# 3                                      ÷ (Deluxe)
# 4                              x (Deluxe Edition)
# ...                                           ...
# 6410  Neste sommer (Jubileumsutgave) [Remastered]
# 6411                                  Voulez-Vous
# 6412                                  Night Moves
# 6413                                    Hits Back
# 6414                                   Girl Power
#
#                                      track_name                track_id  \
# 0                              ...Ready For It?  2yLa0QULdQr0qAIvVwN6B5
# 1                                  Life Changes  4Vxu50qVrQcycjRyJQaZLC
# 2                                     24K Magic  6b8Be6ljOzmkOmFslEb23P
# 3                                   Galway Girl  0afhq8XCExXpqazXczTSve
# 4                                    Photograph  1HNkqx9Ahdgi1Ixy2xkKkL
# ...                                         ...                     ...
# 6410                               Neste sommer  57ZtwfFbKNS3mj8E8ijujU
# 6411                                Voulez-Vous  17OqI90oTFZ3J8PVu6j07V
# 6412                                Night Moves  6UBjSnyP1O5W5ndJoO9vUk
# 6413  Should I Stay or Should I Go - Remastered  3v8PlUFGQQDBIk1J86waCo
# 6414                               Välkommen in  0KfgcINai5NkqsYbOsxOIF
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.613   0.764    2    -6.509     1       0.1360       0.05270
# 1            0.687   0.845    7    -4.370     1       0.0576       0.10000
# 2            0.818   0.803    1    -4.282     1       0.0797       0.03400
# 3            0.624   0.876    9    -3.374     1       0.1000       0.07350
# 4            0.614   0.379    4   -10.480     1       0.0476       0.60700
# ...            ...     ...  ...       ...   ...          ...           ...
# 6410         0.438   0.757   11    -4.799     1       0.0314       0.00199
# 6411         0.708   0.774   11    -6.931     0       0.0372       0.14900
# 6412         0.705   0.743    1    -6.631     1       0.0420       0.43200
# 6413         0.742   0.838    2    -6.442     1       0.1100       0.08320
# 6414         0.626   0.682    0    -7.071     1       0.0351       0.10900
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000000    0.1970    0.417  160.015       208187
# 1             0.000000    0.0452    0.809   87.972       190227
# 2             0.000000    0.1530    0.632  106.970       225983
# 3             0.000000    0.3270    0.781   99.943       170827
# 4             0.000464    0.0986    0.201  107.989       258987
# ...                ...       ...      ...      ...          ...
# 6410          0.000000    0.1050    0.340  106.136       236120
# 6411          0.001090    0.1690    0.903  126.636       309173
# 6412          0.013300    0.1030    0.374  118.552       324423
# 6413          0.000000    0.4180    0.848  113.373       188240
# 6414          0.002850    0.2470    0.627  120.007       212453
#
#       time_signature  cluster
# 0                  4     13.0
# 1                  4     15.0
# 2                  4      3.0
# 3                  4     15.0
# 4                  4      5.0
# ...              ...      ...
# 6410               4      0.0
# 6411               4     18.0
# 6412               4     19.0
# 6413               4      3.0
# 6414               4      3.0
#
# [6415 rows x 19 columns]
