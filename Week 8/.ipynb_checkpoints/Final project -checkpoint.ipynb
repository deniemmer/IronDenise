# %% [markdown]
# ## Final project

# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
df = pd.read_excel('feelings.xlsx')
df
# Out:
#                   Timestamp  \
# 0   2021-02-20 21:56:49.755
# 1   2021-02-20 23:32:52.030
# 2   2021-02-16 21:03:59.071
# 3   2021-03-01 10:03:23.049
# 4   2021-02-27 19:27:54.278
# ..                      ...
# 786 2021-02-22 12:54:28.782
# 787 2021-02-17 04:50:31.193
# 788 2021-02-20 14:17:34.046
# 789 2021-02-28 01:06:59.315
# 790 2021-02-20 05:44:09.306
#
#     1. Do you have a social media account? (e.g., Facebook, Twitter, etc.)  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 786                                                Yes
# 787                                                Yes
# 788                                                Yes
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df[df.isnull().any(axis=1)]
# Out:
#                   Timestamp  \
# 469 2021-02-19 23:59:39.525
# 755 2021-03-06 23:07:04.364
#
#     1. Do you have a social media account? (e.g., Facebook, Twitter, etc.)  \
# 469                                                Yes
# 755                                                Yes
#
#     2. Which social media account do you use usually?  \
# 469                                          Facebook
# 755                                          Facebook
#
#     3. Which device do you usually use to connect social media?  \
# 469                                       Mobile Phone
# 755                                             Tablet
#
#     4. Which type of internet connection do you use?  \
# 469                                Broadband (Wi-Fi)
# 755                                Broadband (Wi-Fi)
#
#     5. How long have you been using a social media account?  \
# 469                                         5-10 years
# 755                                          2-5 years
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 2

# %%
df.dropna(inplace=True)

# %%
print(df.columns)
# Out:
# Index(['Timestamp',
#        '1. Do you have a social media account? (e.g., Facebook, Twitter, etc.)',
#        '2. Which social media account do you use usually?',
#        '3. Which device do you usually use to connect social media?',
#        '4. Which type of internet connection do you use?',
#        '5. How long have you been using a social media account?',
#        '6. How frequently do you post (upload status or add photos/videos) on social media? ',
#        '7. How much time do you spend daily in social media?',
#        '8. When do you usually use social media?',
#        '9. How many friends do you have on social media?',
#        '10. How many friends do you know personally in social media? ',
#        '11. How many groups you are tagged in social media?',
#        '12. What is your main purpose for using social media (e.g. Facebook)?',
#        '13. What contents do you mainly look for in your social media news feed?',
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# df.drop(['4. Which type of internet connection do you use?',
#          '10. In last 30 days, How many times, I cough or snore loudly?',
#          '11. In last 30 days, How many times, I feel too cold?',
#          '12. In last 30 days, How many times, I feel too hot?',
#          '17. In last month, how many times you cannot sleep due to any program or other important case?',
#          '11. How many groups you are tagged in social media?',
#          '12. What is your main purpose for using social media (e.g. Facebook)?',
#          '13. What contents do you mainly look for in your social media news feed?',
#          '16. Have you ever experienced peer pressure due to social media?',
#          '29. Living with-',
#          '30. Body weight (Kg)',
#          '31. Height (m)',
#          '32. Smoking habit',
#          '1. In the past 30 days, do you feel lack of companionship?',
#          '4. In the last 30 days, I feel isolated from others.',
#          '6. In the last 30 days, feeling bad about yourself-or that you are a failure or have let yourself or your family down.',
#          '8. In the last 30 days, moving or speaking so slowly or the opposite-moving around a lot more than usual.',
#          '7. In the last 30 days, I am an outgoing person.',
#          '3. In the last 30 days, I am worrying too much about different things.',
#          '10. In last 30 days, How many times, I cough or snore loudly?',
#          '13. In last 30 days, How many times, I saw bad dreams?',
#          '17. In last month, how many times you cannot sleep due to any program or other important case?',
#          '7. In the last 30 days, I am feeling afraid as if something awful might happen.',
#          '5.  How many hours were you in bed?',
#          '8. In last 30 days, How many times, I had to get up to use the bathroom?',
#          '15. In last 30 days, How many times, I having trouble sleeping for any other reason?',
#          '18. In last month, how many times you face problems to maintain program or other important case?',
#         '23. Marital Status', '24. Religion', '25. Education', '26. Profession', '6. In the last 30 days, people are around me but not with me.',
#         '8. In the last 30 days, I can find companionship when I want it.', '2. In the last 30 days, I an not being able to stop or control worrying', '4. In the last 30 days, I felt trouble in relaxing.',  "5. In the last 30 days, I am being so restless that it's hard to sit still", '3. When have you usually gotten up in the morning?', '1. Do you have a social media account? (e.g., Facebook, Twitter, etc.)', 'Timestamp'], axis = 1, inplace = True)

# %%
df
# Out:
#     2. Which social media account do you use usually?  \
# 0                                            Facebook
# 1                                            Facebook
# 2                                            Facebook
# 3                                             Twitter
# 4                                             Twitter
# ..                                                ...
# 786                                          Facebook
# 787                                          Facebook
# 788                                          Facebook
# 789                                          Facebook
# 790                                           Tiktok
#
#     3. Which device do you usually use to connect social media?  \
# 0                                         Mobile Phone
# 1                                         Mobile Phone
# 2                                         Mobile Phone
# 3                                         Mobile Phone
# ...

# %%
print(df.columns)
# Out:
# Index(['2. Which social media account do you use usually?',
#        '3. Which device do you usually use to connect social media?',
#        '5. How long have you been using a social media account?',
#        '6. How frequently do you post (upload status or add photos/videos) on social media? ',
#        '7. How much time do you spend daily in social media?',
#        '8. When do you usually use social media?',
#        '9. How many friends do you have on social media?',
#        '10. How many friends do you know personally in social media? ',
#        '14.Do you believe social media is a good thing?',
#        '15. When you see something in social media, do you instantly believe it?',
#        '17. Does your emotion get influenced by other's posts (success, failure, loss)? ',
#        '18. Have you ever compared yourself with other’s success or luxurious life?',
#        '19. Do you think, your mental wellbeing would be better if you do not use social media?',
# ...

# %%
df.rename(columns={ 
                   '2. Which social media account do you use usually?': 'most used platform', 
                   '3. Which device do you usually use to connect social media?': 'device type',
                   '5. How long have you been using a social media account?': 'since when',
                   '6. How frequently do you post (upload status or add photos/videos) on social media? ': 'frequency of post',
                   '7. How much time do you spend daily in social media?': 'time spent daily',
                   '8. When do you usually use social media?': 'moment of the day',
                   '9. How many friends do you have on social media?': 'amount of following',
                   '10. How many friends do you know personally in social media? ' :'amount of following you know personally',
                   '14.Do you believe social media is a good thing?' : 'finds social media something good', 
                   '15. When you see something in social media, do you instantly believe it?': 'belive everything in social media',
                   "17. Does your emotion get influenced by other's posts (success, failure, loss)? " : "emotions are influenced by others posts",
                   '18. Have you ever compared yourself with other’s success or luxurious life?' : 'ever compared with others',
                   '19. Do you think, your mental wellbeing would be better if you do not use social media?' : 'your mental health would be better without sm',
                   '20. If answer is yes, are you trying to control that thing and trying to reduce the use of social media?' : 'If yes, are you trying reduce your use',
                   '21. Please write your age in years (number).': 'age',
                   '22. Gender' : 'gender',
                   '27. Monthly income' : 'monthly income',
                   '28. Area of residence': 'area of residence',
                   '2. In the past 30 days, there is no one I can turn to': 'there is anybody I can turn to',
                   '3. In the past 30 days, I feel left out.': 'I feel out',
                   '5. In the last 30 days, I am unhappy being so withdrawn.': 'I feel withdrawn',
                   '1 In the last 30 days, little interest or pleasure in doing things.' : 'no interest in doing things',
                   '2. In the last 30 days, feeling down, depressed or hopeless.' : 'feel depressed or hopeless',
                   '3. In the last 30 days, trouble falling or staying asleep, sleeping too much' : 'sleeping disorder',
                   '4. In the last 30 days, Feeling tired or having little energy.' : 'very tired',
                   '5. In the last 30 days, poor appetite or over-eating.': 'poor appetite or over-eating',
                   '7. In the last 30 days, trouble concentrating on things, such as reading the newspaper or watching television.' : 'trouble concentrating',
                   '9. In the last 30 days, thoughts that you would be better off dead, or of hurting yourself.' : 'suicidal or self harming thoughts',
                   '1. In the last 30 days, I am feeling nervous, anxious, or on edge': 'feeling anxious',
                   '6. In the last 30 days, I becoming easily annoyed or irritable.': 'feelin irritable',
                   '1. When I am usually gone to bed?' : 'gone to bed',
                   '2. How long (in minutes) has it taken you to fall asleep each night?': 'time that takes falling asleep',
                   '4. How many hours of actual sleep do you get at night?': 'hours of sleep',
                   '6. In last 30 days, How many times, I cannot get to sleep within 30 minutes?': "can't sleep within 30 min",
                   '7. In last 30 days, How many times, I wake up in the middle of the night or early morning?' : 'wake up in the middle of the night',
                   '9. In last 30 days, How many times, I cannot breathe comfortably?': "can't breath comfortably",
                   '14. In last 30 days, How many times, I have pain during sleep?' : "have pain during sleep",
                   '16. In last 30 days, In last month, have you take medicines for sleep?' : "take medicinee for sleep",
                   '19. During the past month, how would you rate your sleep quality overall?': 'rate of sleep'}, 
          inplace=True, errors='raise')

# %%
df
# Out:
#     most used platform   device type          since when    frequency of post  \
# 0             Facebook  Mobile Phone          5-10 years  Less than 1 per day
# 1             Facebook  Mobile Phone          5-10 years          3-5 per day
# 2             Facebook  Mobile Phone          5-10 years  Less than 1 per day
# 3              Twitter  Mobile Phone    Less than 2-year  Less than 1 per day
# 4              Twitter  Mobile Phone    Less than 2-year  More than 5 per day
# ..                 ...           ...                 ...                  ...
# 786           Facebook  Mobile Phone  More than 10 years  Less than 1 per day
# 787           Facebook  Mobile Phone          5-10 years  Less than 1 per day
# 788           Facebook  Mobile Phone          5-10 years  More than 5 per day
# 789           Facebook  Mobile Phone           2-5 years  Less than 1 per day
# 790            Tiktok   Mobile Phone  More than 10 years  Less than 1 per day
#
# ...

# %%
df['age'].value_counts()
# Out:
# 2.500000e+01    96
# 2.600000e+01    93
# 2.700000e+01    65
# 2.400000e+01    59
# 2.300000e+01    52
# 1.800000e+01    50
# 2.200000e+01    42
# 1.900000e+01    39
# 1.700000e+01    37
# 2.000000e+01    33
# 2.800000e+01    32
# 2.100000e+01    27
# 2.900000e+01    24
# 1.600000e+01    23
# 3.000000e+01    21
# 1.500000e+01    12
# 3.500000e+01     7
# 3.600000e+01     6
# 3.100000e+01     6
# 3.800000e+01     6
# 3.300000e+01     6
# 1.400000e+01     5
# 3.200000e+01     5
# 4.200000e+01     4
# 3.400000e+01     4
# 4.500000e+01     3
# 4.400000e+01     3
# 4.000000e+01     3
# 4.800000e+01     2
# 4.900000e+01     2
# 5.200000e+01     2
# 1.994000e+03     2
# 5.500000e+01     2
# 3.900000e+01     2
# 1.995000e+03     2
# 4.600000e+01     2
# 5.300000e+01     1
# 2.701710e+12     1
# 6.500000e+01     1
# 1.996000e+03     1
# 2.680000e+01     1
# 1.856420e+09     1
# 3.700000e+01     1
# 6.200000e+01     1
# 4.300000e+01     1
# 1.982000e+03     1
# Name: age, dtype: int64

# %%
df.at[84,'age']='27'
df.at[290,'age']='28'
df.at[332,'age']='27'
df.at[511,'age']='26'
df.at[573,'age']='28'
df.at[786,'age']='40'

# %%
df = df.drop([391 , 552, 586])

# %%
df= df.drop([df.index[391], df.index[552], df.index[586]])
# Out:
#   File "/var/folders/qg/crcztcy17rbfrp2nsq_7_5lw0000gn/T/ipykernel_28036/2119472030.py", line 1
#     df= df.drop([df.index[391], df.index[552], df.index[586], inplace= True])
#                                                                      ^
# SyntaxError: invalid syntax

# %%
df['age'].value_counts()
# Out:
# 25.0               94
# 26.0               91
# 27.0               63
# 24.0               58
# 18.0               50
# 23.0               50
# 22.0               42
# 17.0               37
# 19.0               37
# 20.0               33
# 28.0               32
# 21.0               26
# 29.0               24
# 16.0               22
# 30.0               21
# 15.0               12
# 36.0                6
# 33.0                6
# 31.0                6
# 38.0                6
# 35.0                6
# 14.0                5
# 42.0                4
# 34.0                4
# 32.0                4
# 45.0                3
# 44.0                3
# 40.0                3
# 48.0                2
# 49.0                2
# 55.0                2
# 28                  2
# 52.0                2
# 39.0                2
# 27                  2
# 1995.0              2
# 46.0                2
# 1994.0              2
# 1856420137.0        1
# 1982.0              1
# 43.0                1
# ...

# %%
df.index[391]
# Out:
# 394

# %%
df = df.drop([[391] ,[552], [586]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/qg/crcztcy17rbfrp2nsq_7_5lw0000gn/T/ipykernel_28036/1827843845.py in <module>
# ----> 1 df = df.drop([[391] ,[552], [586]])
#
# /opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4946                 weight  1.0     0.8
#    4947         """
# -> 4948         return super().drop(
#    4949             labels=labels,
#    4950             axis=axis,
#
# ...

# %%
df.index[391]
# Out:
# 394

# %%
df
# Out:
#     most used platform   device type          since when    frequency of post  \
# 0             Facebook  Mobile Phone          5-10 years  Less than 1 per day
# 1             Facebook  Mobile Phone          5-10 years          3-5 per day
# 2             Facebook  Mobile Phone          5-10 years  Less than 1 per day
# 3              Twitter  Mobile Phone    Less than 2-year  Less than 1 per day
# 4              Twitter  Mobile Phone    Less than 2-year  More than 5 per day
# ..                 ...           ...                 ...                  ...
# 786           Facebook  Mobile Phone  More than 10 years  Less than 1 per day
# 787           Facebook  Mobile Phone          5-10 years  Less than 1 per day
# 788           Facebook  Mobile Phone          5-10 years  More than 5 per day
# 789           Facebook  Mobile Phone           2-5 years  Less than 1 per day
# 790            Tiktok   Mobile Phone  More than 10 years  Less than 1 per day
#
# ...
